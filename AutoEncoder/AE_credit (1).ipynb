# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/creditcard.csv', on_bad_lines='skip')
# Out:
# /tmp/ipython-input-3290124573.py:1: DtypeWarning: Columns (0,9,13,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/creditcard.csv', on_bad_lines='skip')

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
df.shape
# Out:
# (106550, 31)

# %%
# 결측치 홗인

df.isnull().values.any()
# Out:
# np.True_

# %%
LABELS = ["Normal", "Fraud"]

# %%
count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");
# Out:
# /tmp/ipython-input-2107955042.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   count_classes = pd.value_counts(df['Class'], sort = True)

# %%
frauds = df[df.Class == 1]
normal = df[df.Class == 0]
frauds.shape
# Out:
# (188, 31)

# %%
normal.shape
# Out:
# (106351, 31)

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Amount per transaction by class')

bins = 50

ax1.hist(frauds.Amount, bins = bins)
ax1.set_title('Fraud')

ax2.hist(normal.Amount, bins = bins)
ax2.set_title('Normal')

plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.xlim((0, 20000))
plt.yscale('log')
plt.show();

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')

ax1.scatter(frauds.Time, frauds.Amount)
ax1.set_title('Fraud')

ax2.scatter(normal.Time, normal.Amount)
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3231404958.py in <cell line: 0>()
#       2 f.suptitle('Time of transaction vs Amount by class')
#       3
# ----> 4 ax1.scatter(frauds.Time, frauds.Amount)
#       5 ax1.set_title('Fraud')
#       6
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4892         edgecolors = kwargs.pop('edgecolor', None)
#    4893         # Process **kwargs to handle aliases, conflicts with explicit kwargs:
# -> 4894         x, y = self._process_unit_info([("x", x), ("y", y)], kwargs)
#    4895         # np.ma.ravel yields an ndarray, not a masked array,
#    4896         # unless its argument is a masked array.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in _process_unit_info(self, datasets, kwargs, convert)
#    2615             # Update from data if axis is already set but no unit is set yet.
#    2616             if axis is not None and data is not None and not axis.have_units():
# -> 2617                 axis.update_units(data)
#    2618         for axis_name, axis in axis_map.items():
#    2619             # Return if no axis is set.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in update_units(self, data)
#    1763         neednew = self._converter != converter
#    1764         self._set_converter(converter)
# -> 1765         default = self._converter.default_units(data, self)
#    1766         if default is not None and self.units is None:
#    1767             self.set_units(default)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/category.py in default_units(data, axis)
#     104         # the conversion call stack is default_units -> axis_info -> convert
#     105         if axis.units is None:
# --> 106             axis.set_units(UnitData(data))
#     107         else:
#     108             axis.units.update(data)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/category.py in __init__(self, data)
#     180         self._counter = itertools.count()
#     181         if data is not None:
# --> 182             self.update(data)
#     183
#     184     @staticmethod
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/category.py in update(self, data)
#     215         for val in OrderedDict.fromkeys(data):
#     216             # OrderedDict just iterates over unique values in data.
# --> 217             _api.check_isinstance((str, bytes), value=val)
#     218             if convertible:
#     219                 # this will only be called so long as convertible is True.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/__init__.py in check_isinstance(types, **kwargs)
#      90                 names.remove("None")
#      91                 names.append("None")
# ---> 92             raise TypeError(
#      93                 "{!r} must be an instance of {}, not a {}".format(
#      94                     k,
#
# TypeError: 'value' must be an instance of str or bytes, not a int

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/creditcard.csv', on_bad_lines='skip')

# Convert 'Time' and 'Amount' columns to numeric, coercing errors to NaN
df['Time'] = pd.to_numeric(df['Time'], errors='coerce')
df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')

# Drop rows where 'Time' or 'Amount' became NaN due to coercion
df.dropna(subset=['Time', 'Amount'], inplace=True)
# Out:
# /tmp/ipython-input-1158984057.py:1: DtypeWarning: Columns (0,9,13,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/creditcard.csv', on_bad_lines='skip')

# %%
from sklearn.preprocessing import StandardScaler

data = df.drop(['Time'], axis=1)

# Ensure all columns in 'data' are numeric
for col in data.columns:
    data[col] = pd.to_numeric(data[col], errors='coerce')

# Drop rows with NaN values that might have been introduced during coercion
data.dropna(inplace=True)

data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))

# %%
# 모델을 오직 정상 거래기록으로만 훈련
# 정상 거래기록을 테스트셋에 넣으면 모델의 성능을 평가

# %%
RANDOM_SEED = 42

# %%
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)

y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)

X_train = X_train.values
X_test = X_test.values

X_train.shape
# Out:
# (85078, 29)

# %%
# 테스트 레이블을 남겨두는 이유는 나중에 정확도를 비교하기 위해서임

# %%
# 오토인코더 모델

input_dim = X_train.shape[1]
encoding_dim = 14  # 인코딩 차원을 설정 (임의로 설정한 값, 조정 가능)

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
encoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# %%
# 3. 모델 학습
# 훈련데이터의 0.1 을 validation data로 사용
history = autoencoder.fit(X_train, X_train,
                          epochs=50,
                          batch_size=256,
                          shuffle=True,
                          validation_split = 0.1)
# Out:
# Epoch 1/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.2879 - val_loss: 1.0181
# Epoch 2/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0315 - val_loss: 0.9660
# Epoch 3/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9470 - val_loss: 0.9273
# Epoch 4/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9168 - val_loss: 0.9104
# Epoch 5/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9251 - val_loss: 0.9021
# Epoch 6/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9139 - val_loss: 0.8967
# Epoch 7/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0102 - val_loss: 0.8928
# Epoch 8/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9195 - val_loss: 0.8892
# Epoch 9/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.9438 - val_loss: 0.8859
# Epoch 10/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8886 - val_loss: 0.8818
# Epoch 11/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.9665 - val_loss: 0.8789
# Epoch 12/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8966 - val_loss: 0.8768
# Epoch 13/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8929 - val_loss: 0.8746
# Epoch 14/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8839 - val_loss: 0.8731
# Epoch 15/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9142 - val_loss: 0.8719
# Epoch 16/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9202 - val_loss: 0.8708
# Epoch 17/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9062 - val_loss: 0.8697
# Epoch 18/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8833 - val_loss: 0.8686
# Epoch 19/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9090 - val_loss: 0.8677
# Epoch 20/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8563 - val_loss: 0.8665
# Epoch 21/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.9120 - val_loss: 0.8660
# Epoch 22/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8526 - val_loss: 0.8653
# Epoch 23/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8782 - val_loss: 0.8644
# Epoch 24/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8916 - val_loss: 0.8641
# Epoch 25/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8935 - val_loss: 0.8636
# Epoch 26/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8952 - val_loss: 0.8632
# Epoch 27/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8707 - val_loss: 0.8627
# Epoch 28/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8834 - val_loss: 0.8626
# Epoch 29/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8825 - val_loss: 0.8620
# Epoch 30/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8812 - val_loss: 0.8617
# Epoch 31/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8689 - val_loss: 0.8615
# Epoch 32/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.9138 - val_loss: 0.8614
# Epoch 33/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.9005 - val_loss: 0.8610
# Epoch 34/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8609 - val_loss: 0.8610
# Epoch 35/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8933 - val_loss: 0.8608
# Epoch 36/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9680 - val_loss: 0.8603
# Epoch 37/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8814 - val_loss: 0.8589
# Epoch 38/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9212 - val_loss: 0.8585
# Epoch 39/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.8809 - val_loss: 0.8579
# Epoch 40/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8922 - val_loss: 0.8577
# Epoch 41/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8691 - val_loss: 0.8576
# Epoch 42/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9502 - val_loss: 0.8574
# Epoch 43/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8477 - val_loss: 0.8574
# Epoch 44/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.8906 - val_loss: 0.8573
# Epoch 45/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8658 - val_loss: 0.8570
# Epoch 46/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9510 - val_loss: 0.8569
# Epoch 47/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8887 - val_loss: 0.8569
# Epoch 48/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8959 - val_loss: 0.8565
# Epoch 49/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9255 - val_loss: 0.8567
# Epoch 50/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.8653 - val_loss: 0.8567

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
# X_test 값을 넣어서 Reconstruction Error 값을 얻고,
# 실제 레이블인 y_test와 데이터프레임으로 구성
# Reconstruction Error + 실제 레이블의 형태가 됨

predictions = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df.describe()
# Out:
# 666/666 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#        reconstruction_error    true_class
# count          21308.000000  21308.000000
# mean               0.912154      0.001643
# std                4.355570      0.040496
# min                0.083878      0.000000
# 25%                0.285719      0.000000
# 50%                0.453294      0.000000
# 75%                0.740977      0.000000
# max              206.303287      1.000000

# %%
error_df.head()
# Out:
#        reconstruction_error  true_class
# 58700              0.952557         0.0
# 47050              0.935104         0.0
# 68338              0.514629         0.0
# 4891               0.629617         0.0
# 91733              0.628981         0.0

# %%
# threshold 값을 조정하여 최선의 정확도를 얻음, 그래프로를 보고 결정

threshold = 15

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

print(classification_report(error_df.true_class, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     21273
#          1.0       0.09      0.26      0.14        35
#
#     accuracy                           0.99     21308
#    macro avg       0.55      0.63      0.57     21308
# weighted avg       1.00      0.99      1.00     21308
